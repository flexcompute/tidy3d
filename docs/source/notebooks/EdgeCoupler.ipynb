# %% [markdown]
# # Inverse taper edge coupler

# %% [markdown]
# Note: The cost of running the entire notebook is higher than 1 FlexCredit.
#
# Fiber-to-chip couplers are essential components in photonic integrated circuits (PICs) that need to couple in/out light using optical fibers. However, the huge mismatch between the mode sizes of a single mode fiber ($\approx 10\mu m$ in diameter) and a silicon wire waveguide (220 x 500 nm) can cause significant coupling loss if they are coupled directly. For this reason, the design of the fiber-to-chip coupling devices is critical for the whole system's performance and needs to be carefully accomplished. There are two main categories of fiber-to-chip optical coupling devices: [grating couplers](https://www.flexcompute.com/tidy3d/examples/notebooks/GratingCoupler/), where the optical fiber is positioned perpendicularly to the chip plane; and edge couplers, which allow in-plane light coupling by the direct alignment between the fiber and the integrated waveguide facets.
#
# In this notebook, we will show an example of using Tidy3D to evaluate the performance of edge couplers built using inverted taper mode transformers of linear, quadratic, and exponential profiles. We will also see how to set up a [Gaussian beam](../_autosummary/tidy3d.GaussianBeam.html) to simulate the field launched by a lensed fiber and the use of [Batch](../_autosummary/tidy3d.web.Batch.html) simulations to perform parameter sweeps.
#
# For more integrated photonic examples such as the [8-Channel mode and polarization de-multiplexer](https://www.flexcompute.com/tidy3d/examples/notebooks/8ChannelDemultiplexer/), the [broadband bi-level taper polarization rotator-splitter](https://www.flexcompute.com/tidy3d/examples/notebooks/BilevelPSR/), and the [broadband directional coupler](https://www.flexcompute.com/tidy3d/examples/notebooks/BroadbandDirectionalCoupler/), please visit our [examples page](https://www.flexcompute.com/tidy3d/examples/).

# %% [markdown]
# We start by importing the necessary modules:

# %%
# standard python imports
import numpy as np
import matplotlib.pyplot as plt

# Tidy3D imports
import tidy3d as td
import tidy3d.web as web

# %% [markdown]
# ## Simulation Setup
#
# The inverted taper structure is made using an SOI platform consisting of a silicon (Si) substrate, a 3 $\mu m$ thick silicon dioxide (SiO2) layer, and a 220 nm thick silicon layer covered by 3 $\mu m$ thick silicon dioxide. As shown in the image below, the inverted taper is defined at the 220 nm thick Si layer, and its main geometric parameters are also defined in the figure. An optical fiber mode with a Gaussian profile (2.5 $\mu m$ spot-size) is focused at the taper tip and coupled into the output waveguide.
#
# <img src="img/EdgeCoupler.png" alt="Schematic of the inverted taper edge coupler"  width="400"/>

# %% [markdown]
# Definition of the simulation wavelength and materials.

# %%
wl_c = 1.55  # Central wavelength.
wl_bw = 0.100  # Wavelength bandwidth.
wl_n = 101  # Number of wavelength points to compute the output data.

mat_si = td.Medium(permittivity=3.48**2)  # Taper and substrate material.
mat_sio2 = td.Medium(permittivity=1.44**2)  # Box and cladding material.
mat_air = td.Medium(permittivity=1.00)  # External medium material.

# %% [markdown]
# Definition of the taper size, lensed fiber parameters, and SOI structure.

# %%
taper_l = 25  # Taper length.
taper_w_in = 0.19  # Taper tip width.
taper_w_out = 0.50  # Taper output width.
taper_t = 0.22  # Taper thickness.

# Spot size of the gaussian mode launched by the lensed fiber at the taper tip.
spot_size = 2.5

box_thick = 3.0  # Silicon dioxide box layer.
clad_thick = 3.0  # Silicon dioxide layer covering the taper.

# %% [markdown]
# Calculated parameters and constants used in the simulation set up.

# %%
# Extra space around the taper at x,y directions.
pad_x = 1 * wl_c
pad_y = 1.5 * wl_c

# Wavelength and frequency values.
wl_range = np.linspace(wl_c - wl_bw / 2, wl_c + wl_bw / 2, wl_n)
freq_c = td.C_0 / wl_c
freq_range = td.C_0 / wl_range
freq_width = 0.5 * (np.max(freq_range) - np.min(freq_range))
run_time = 30 / freq_width

# Large number to be used in replacement of td.inf when necessary.
_inf = 1e3

# %% [markdown]
# Function to create the inverted taper geometry based on the work of [G. Ren et al. (2013)](https://www.sciencedirect.com/science/article/abs/pii/S0030401811006389).

# %%
# List of inverted tapers names.
tap_names = ["linear", "quadratic", "exponential"]


def get_taper(
    taper_shape="linear",
    init_coord=[pad_x, taper_w_in / 2],
    end_coord=[pad_x + taper_l, taper_w_out / 2],
):
    """Return a polygon composed of the taper vertices given the desired shape."""

    x0 = init_coord[0]
    x1 = end_coord[0]
    y0 = init_coord[1]
    y1 = end_coord[1]
    x = np.linspace(x0, x1, 41)

    tap_name = "linear_tap"
    if taper_shape == "quadratic":
        alpha = ((x - x0) / (x1 - x0)) ** 2
        tap_name = "quadratic_tap"
    elif taper_shape == "exponential":
        alpha = np.expm1((x - x0) / (x1 - x0)) / np.expm1(1)
        tap_name = "exponential_tap"
    elif taper_shape == "linear":
        alpha = (x - x0) / (x1 - x0)
    else:
        print(
            "taper_shape is neither 'linear', 'quadratic', or 'exponential'!\n"
            + "Linear taper shape returned!"
        )
        alpha = (x - x0) / (x1 - x0)

    y = y0 + alpha * (y1 - y0)
    upper_bound = [[xv, yv] for xv, yv in zip(x, y)] + [[_inf, y1]]
    lower_bound = [[_inf, -y1]] + [[xv, -yv] for xv, yv in zip(x[::-1], y[::-1])]
    taper_polygon = upper_bound + lower_bound

    # Inverted taper structure using a PolySlab.
    taper = td.Structure(
        geometry=td.PolySlab(
            vertices=taper_polygon, axis=2, slab_bounds=(-taper_t / 2, taper_t / 2)
        ),
        medium=mat_si,
        name=tap_name,
    )
    return taper

# %% [markdown]
# Function to create the simulation object. Since the box and cladding oxide layers are considerably thick, the silicon substrate and the upper air layer will be removed from the simulation, so being possible to take advantage of the symmetry along the z-axis. In addition, we will insert the Gaussian source directly into the taper tip to reduce the simulation cost further.

# %%
def get_simulations(
    tap_length=taper_l,
    tap_w_in=taper_w_in,
    tap_w_out=taper_w_out,
    tap_t=taper_t,
    tap_names=tap_names,
):
    """Return a dict of simulation objects for the content of 'tap_names'."""

    size_x = tap_length + 2 * pad_x
    size_y = tap_w_out + 2 * pad_y
    size_z = box_thick + clad_thick + tap_t

    # Gaussian source focused at the taper tip.
    # The Gaussian source must be placed at a plane within a uniform medium.
    gauss_source = td.GaussianBeam(
        center=(0.99 * pad_x, 0, 0),
        size=(0, size_y, size_z),
        source_time=td.GaussianPulse(freq0=freq_c, fwidth=freq_width),
        pol_angle=0,
        direction="+",
        num_freqs=7,
        waist_radius=spot_size / 2,
    )

    # Field monitor to visualize the fields throughout the length of the taper.
    field_monitor_xy = td.FieldMonitor(
        center=(size_x / 2, 0, 0),
        size=(size_x, size_y, 0),
        freqs=[freq_c],
        name="field_xy",
    )

    # Field monitor to visualize the Gaussian input fields.
    field_input = td.FieldMonitor(
        center=(pad_x, 0, 0),
        size=(0, size_y, size_z),
        freqs=[freq_c],
        name="field_input",
    )

    # Field monitor to visualize the fields at the output waveguide.
    field_output = td.FieldMonitor(
        center=(size_x - pad_x / 2, 0, 0),
        size=(0, size_y, size_z),
        freqs=[freq_c],
        name="field_output",
    )

    # Mode monitor to get the power coupled into the fundamental TE mode.
    mode_spec = td.ModeSpec(num_modes=1)
    mode_monitor = td.ModeMonitor(
        center=(size_x - pad_x / 2, 0, 0),
        size=(0, size_y, size_z),
        freqs=freq_range,
        mode_spec=mode_spec,
        name="mode_0",
    )

    # Silicon dioxide box + cladding layers
    sio2_medium = td.Structure(
        geometry=td.Box.from_bounds(
            rmin=(pad_x, -_inf, -_inf), rmax=(_inf, _inf, _inf)
        ),
        medium=mat_sio2,
    )

    # Simulation definition
    sim_tap = []
    for t_name in tap_names:
        taper_poly = get_taper(
            t_name,
            init_coord=[pad_x, tap_w_in / 2],
            end_coord=[size_x - pad_x, tap_w_out / 2],
        )

        sim_tap.append(
            td.Simulation(
                center=(size_x / 2, 0, 0),
                size=(size_x, size_y, size_z),
                medium=mat_air,
                grid_spec=td.GridSpec.auto(min_steps_per_wvl=15, wavelength=wl_c),
                structures=[sio2_medium, taper_poly],
                sources=[gauss_source],
                normalize_index=0,
                monitors=[field_monitor_xy, field_input, field_output, mode_monitor],
                boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML(num_layers=20)),
                symmetry=(0, -1, 1),
                run_time=run_time,
            )
        )
    sims = {sim_name: sim for sim_name, sim in zip(tap_names, sim_tap)}
    return sims

# %% [markdown]
# ## Comparison between inverted tapers with different shapes.
#
# We start our analysis by comparing the response of inverted tapers with 3 different geometries: linear, quadratic, and exponential. Then, before running the simulations, we will visualize the shapes of the inverted tapers and examine the simulation set up to see if everything is correct.

# %%
# Get the list of simulation objects.
sim_tap = get_simulations(tap_length=taper_l)
# Out:
# [10:42:45] WARNING: Default value for the field monitor           ]8;id=967155;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=745308;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            WARNING: Default value for the field monitor           ]8;id=980571;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=744680;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            WARNING: Default value for the field monitor           ]8;id=421853;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=92382;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.

# %%
# Structure visualization.
fig, axs = plt.subplots(3, 1, tight_layout=True, figsize=(8, 6))
for sim_s, tap_n, ax in zip(sim_tap.values(), sim_tap.keys(), axs):
    sim_s.plot_structures(z=0, ax=ax)
    ax.set_xlim(0, 2 * pad_x + taper_l)
    ax.set_ylim(-1.5 * taper_w_out / 2, 1.5 * taper_w_out / 2)
    ax.set_aspect("auto")  # Used to better visualize the shapes.
    ax.set_title(tap_n)
plt.show()

# %%
# Simulation set up visualization.
fig = plt.figure(tight_layout=True, figsize=(8, 6))
gs = fig.add_gridspec(2, 2)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[1, 1])
sim_tap["linear"].plot(z=0, ax=ax1)
sim_tap["linear"].plot(x=pad_x, ax=ax2)
sim_tap["linear"].plot(x=pad_x + taper_l + pad_x / 2, ax=ax3)
plt.show()

# %% [markdown]
# Now, we will run the simulations using a batch object.

# %%
# Initialize a simulation batch.
batch = web.Batch(simulations=sim_tap, verbose=True)

# Get the estimated simulation cost.
tot_cost = 0
for bat in batch.get_info().values():
    sim_name = bat.taskName
    cost = web.estimate_cost(bat.taskId)
    tot_cost += cost
    print(f"Estimated FlexCredit cost for {sim_name} = {cost:.2f}")
print(f"Total estimated FlexCredit cost for batch = {tot_cost:.2f}")
# Out:
# [10:42:46] Created task 'linear' with task_id                      ]8;id=527371;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=833554;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-5d979688-1969-4038-97c6-d1044b97e4ecv1'.
#            View task using web UI at                               ]8;id=179385;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=694454;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=862605;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5d979688-1969-4038-97c6-d1044b97e4ecv1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=96340;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5d979688-1969-4038-97c6-d1044b97e4ecv1\taskId]8;;\]8;id=862605;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5d979688-1969-4038-97c6-d1044b97e4ecv1\=]8;;\]8;id=464678;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5d979688-1969-4038-97c6-d1044b97e4ecv1\fdve]8;;\]8;id=862605;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5d979688-1969-4038-97c6-d1044b97e4ecv1\-]8;;\
#            ]8;id=862605;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5d979688-1969-4038-97c6-d1044b97e4ecv1\5d979688-1969-4038-97c6-d1044b97e4ecv1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:42:47] Created task 'quadratic' with task_id                   ]8;id=823297;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=280810;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-2e8050ec-de31-42be-bc61-2726aa98e9edv1'.
#            View task using web UI at                               ]8;id=120152;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=546317;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=580421;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2e8050ec-de31-42be-bc61-2726aa98e9edv1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=664513;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2e8050ec-de31-42be-bc61-2726aa98e9edv1\taskId]8;;\]8;id=580421;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2e8050ec-de31-42be-bc61-2726aa98e9edv1\=]8;;\]8;id=873098;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2e8050ec-de31-42be-bc61-2726aa98e9edv1\fdve]8;;\]8;id=580421;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2e8050ec-de31-42be-bc61-2726aa98e9edv1\-]8;;\
#            ]8;id=580421;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2e8050ec-de31-42be-bc61-2726aa98e9edv1\2e8050ec-de31-42be-bc61-2726aa98e9edv1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            Created task 'exponential' with task_id                 ]8;id=320685;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=547;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1'.
#            View task using web UI at                               ]8;id=654377;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=901528;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=124622;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=534652;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1\taskId]8;;\]8;id=124622;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1\=]8;;\]8;id=570140;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1\fdve]8;;\]8;id=124622;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1\-]8;;\
#            ]8;id=124622;https://tidy3d.simulation.cloud/workbench?taskId=fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1\3ffa54b6-43f7-4308-9cac-2e775c1f40c7v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Estimated FlexCredit cost for linear = 0.12
# Estimated FlexCredit cost for quadratic = 0.12
# Estimated FlexCredit cost for exponential = 0.12
# Total estimated FlexCredit cost for batch = 0.36

# %% [markdown]
# Run the batch and store all of the data in the `data_taper` dir.

# %%
batch_taper = batch.run(path_dir="data/data_taper")
# Out:
# [10:43:04] Started working on Batch.                            ]8;id=243554;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:]8;id=465894;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py#475\475]8;;\
# [10:43:19] Maximum FlexCredit cost: 0.356 for the whole batch.  ]8;id=405607;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:]8;id=444330;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py#479\479]8;;\
#            Use 'Batch.real_cost()' to get the billed FlexCredit
#            cost after the Batch has completed.
# Output()
# [10:44:57] Batch complete.                                      ]8;id=943741;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:]8;id=539983;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py#522\522]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Inverted taper results
# Now we will see the field intensity and the modal coupling efficiency for the 3 inverted tapers.

# %%
sim_tap_results = {tl: sn for tl, sn in batch_taper.items()}
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:45:00] loading SimulationData from                             ]8;id=108578;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=358295;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_taper/fdve-5d979688-1969-4038-97c6-d1044b97e4
#            ecv1.hdf5
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:45:01] loading SimulationData from                             ]8;id=949809;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=94057;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_taper/fdve-2e8050ec-de31-42be-bc61-2726aa98e9
#            edv1.hdf5
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:45:02] loading SimulationData from                             ]8;id=449164;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=382744;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_taper/fdve-3ffa54b6-43f7-4308-9cac-2e775c1f40
#            c7v1.hdf5

# %%
fig, axs = plt.subplots(3, 1, tight_layout=True, figsize=(10, 8))
for tap_n, sim_data, ax in zip(sim_tap_results.keys(), sim_tap_results.values(), axs):
    sim_data.plot_field("field_xy", "Ey", f=freq_c, val="abs", ax=ax)
    ax.set_title(tap_n)
    ax.set_aspect("auto")  # Used to better visualize the shapes.
plt.show()

# %% [markdown]
# Bellow, we have the $|E_{y}|$ field recorded by the monitors positioned at the taper tip and taper output of the quadratic structure. We can clearly visualize the Gaussian profile corresponding to the fields launched by a lensed fiber at the taper tip. In contrast, the output field corresponds to the transverse electric polarization of the fundamental output waveguide mode.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(8, 4))
sim_tap_results["quadratic"].plot_field(
    "field_input", "Ey", f=freq_c, val="abs", ax=ax1
)
ax1.set_title("|Ey| at taper tip")
ax1.collections[-1].set_clim(0, 20)
ax1.set_xlim(-2, 2)
ax1.set_ylim(-2, 2)

sim_tap_results["quadratic"].plot_field(
    "field_output", "Ey", f=freq_c, val="abs", ax=ax2
)
ax2.set_title("|Ey| at taper output")
ax2.collections[-1].set_clim(0, 50)
ax2.set_xlim(-2, 2)
ax2.set_ylim(-2, 2)
plt.show()

# %% [markdown]
# The modal coupling efficiencies shown below reveal that the quadratic taper profile has the lowest insertion losses.

# %%
power_tap_25 = []
for sim_data in sim_tap_results.values():
    mode_amps = sim_data["mode_0"]
    coeffs_f = mode_amps.amps.sel(direction="+")
    power_0 = np.abs(coeffs_f.sel(mode_index=0)) ** 2
    power_0_db = 10 * np.log10(power_0)
    power_tap_25.append(power_0_db)

plot_colors = ("black", "red", "blue")
fig, ax1 = plt.subplots(1, figsize=(8, 4))
for data, color, label in zip(power_tap_25, plot_colors, sim_tap_results.keys()):
    ax1.plot(
        wl_range,
        data,
        color=color,
        linestyle="solid",
        linewidth=1.0,
        label=label,
    )
ax1.set_xlim([wl_range[0], wl_range[-1]])
ax1.set_xlabel("Wavelength (um)")
ax1.set_ylabel("Power (dB)")
ax1.set_title("Coupling Efficiency")
plt.legend()
plt.show()

# %% [markdown]
# ## Inverted Taper Length Sweep
# Before, we simulated the inverted tapers with a short length of only 25 $\mu m$ to improve simulation time. Nevertheless, the designs can be improved by making the inverted taper larger in length so that its adiabaticity is increased. In the following sections, we increase the taper length to 50 $\mu m$ and 100 $\mu m$ (other values can be added to the sweep at a higher simulation cost).

# %%
# Taper lengths on the sweep.
taper_sweep = [50, 100]
sim_sweep = [get_simulations(tap_length=t_l) for t_l in taper_sweep]

# Make a dictionary of {task name : simulation}
sims = {
    f"sim_{tap_l}_{sim_name}": sim
    for sim_l, tap_l in zip(sim_sweep, taper_sweep)
    for sim, sim_name in zip(sim_l.values(), sim_l.keys())
}
# Initialize a batch and run them all
batch = web.Batch(simulations=sims, verbose=True)

# Get the estimated simulation cost.
tot_cost = 0
for bat in batch.get_info().values():
    sim_name = bat.taskName
    cost = web.estimate_cost(bat.taskId)
    tot_cost += cost
    print(f"Estimated FlexCredit cost for {sim_name} = {cost:.2f}")
print(f"Total estimated FlexCredit cost for batch = {tot_cost:.2f}")
# Out:
# [10:45:06] WARNING: Default value for the field monitor           ]8;id=551524;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=311506;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            WARNING: Default value for the field monitor           ]8;id=895680;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=871406;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            WARNING: Default value for the field monitor           ]8;id=390894;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=450798;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            WARNING: Default value for the field monitor           ]8;id=121092;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=708684;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            WARNING: Default value for the field monitor           ]8;id=234469;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=554089;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            WARNING: Default value for the field monitor           ]8;id=681389;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=496084;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
#            Created task 'sim_50_linear' with task_id               ]8;id=466990;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=600660;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-e63eb20f-a799-4257-9dee-b157bdd6c597v1'.
#            View task using web UI at                               ]8;id=871030;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=493306;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=257823;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e63eb20f-a799-4257-9dee-b157bdd6c597v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=23160;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e63eb20f-a799-4257-9dee-b157bdd6c597v1\taskId]8;;\]8;id=257823;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e63eb20f-a799-4257-9dee-b157bdd6c597v1\=]8;;\]8;id=920946;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e63eb20f-a799-4257-9dee-b157bdd6c597v1\fdve]8;;\]8;id=257823;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e63eb20f-a799-4257-9dee-b157bdd6c597v1\-]8;;\
#            ]8;id=257823;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e63eb20f-a799-4257-9dee-b157bdd6c597v1\e63eb20f-a799-4257-9dee-b157bdd6c597v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            Created task 'sim_50_quadratic' with task_id            ]8;id=121630;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=784476;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-5e0478e3-9049-44b7-b1cd-353a38150273v1'.
#            View task using web UI at                               ]8;id=308713;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=398577;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=274370;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5e0478e3-9049-44b7-b1cd-353a38150273v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=123022;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5e0478e3-9049-44b7-b1cd-353a38150273v1\taskId]8;;\]8;id=274370;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5e0478e3-9049-44b7-b1cd-353a38150273v1\=]8;;\]8;id=673854;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5e0478e3-9049-44b7-b1cd-353a38150273v1\fdve]8;;\]8;id=274370;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5e0478e3-9049-44b7-b1cd-353a38150273v1\-]8;;\
#            ]8;id=274370;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5e0478e3-9049-44b7-b1cd-353a38150273v1\5e0478e3-9049-44b7-b1cd-353a38150273v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:45:07] Created task 'sim_50_exponential' with task_id          ]8;id=302012;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=736233;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-1ea8dfac-9552-4028-a214-22dc3d4243b9v1'.
#            View task using web UI at                               ]8;id=496092;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=650008;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=992124;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1ea8dfac-9552-4028-a214-22dc3d4243b9v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=265180;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1ea8dfac-9552-4028-a214-22dc3d4243b9v1\taskId]8;;\]8;id=992124;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1ea8dfac-9552-4028-a214-22dc3d4243b9v1\=]8;;\]8;id=234162;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1ea8dfac-9552-4028-a214-22dc3d4243b9v1\fdve]8;;\]8;id=992124;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1ea8dfac-9552-4028-a214-22dc3d4243b9v1\-]8;;\
#            ]8;id=992124;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1ea8dfac-9552-4028-a214-22dc3d4243b9v1\1ea8dfac-9552-4028-a214-22dc3d4243b9v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            Created task 'sim_100_linear' with task_id              ]8;id=125094;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=780341;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-7bc37c92-8756-494d-8fce-7b6231adfbd4v1'.
#            View task using web UI at                               ]8;id=468512;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=160854;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=751046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bc37c92-8756-494d-8fce-7b6231adfbd4v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=28799;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bc37c92-8756-494d-8fce-7b6231adfbd4v1\taskId]8;;\]8;id=751046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bc37c92-8756-494d-8fce-7b6231adfbd4v1\=]8;;\]8;id=30522;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bc37c92-8756-494d-8fce-7b6231adfbd4v1\fdve]8;;\]8;id=751046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bc37c92-8756-494d-8fce-7b6231adfbd4v1\-]8;;\
#            ]8;id=751046;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7bc37c92-8756-494d-8fce-7b6231adfbd4v1\7bc37c92-8756-494d-8fce-7b6231adfbd4v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:45:08] Created task 'sim_100_quadratic' with task_id           ]8;id=653832;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=949667;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-d19b5467-c980-4fb4-bc99-e10392bdd773v1'.
#            View task using web UI at                               ]8;id=393573;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=691295;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=712022;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d19b5467-c980-4fb4-bc99-e10392bdd773v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=816612;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d19b5467-c980-4fb4-bc99-e10392bdd773v1\taskId]8;;\]8;id=712022;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d19b5467-c980-4fb4-bc99-e10392bdd773v1\=]8;;\]8;id=904067;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d19b5467-c980-4fb4-bc99-e10392bdd773v1\fdve]8;;\]8;id=712022;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d19b5467-c980-4fb4-bc99-e10392bdd773v1\-]8;;\
#            ]8;id=712022;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d19b5467-c980-4fb4-bc99-e10392bdd773v1\d19b5467-c980-4fb4-bc99-e10392bdd773v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            Created task 'sim_100_exponential' with task_id         ]8;id=801993;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=538227;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-f241b93a-ce58-41bf-900e-4b4d19a2b086v1'.
#            View task using web UI at                               ]8;id=781348;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=831561;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=733803;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f241b93a-ce58-41bf-900e-4b4d19a2b086v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=490970;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f241b93a-ce58-41bf-900e-4b4d19a2b086v1\taskId]8;;\]8;id=733803;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f241b93a-ce58-41bf-900e-4b4d19a2b086v1\=]8;;\]8;id=117384;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f241b93a-ce58-41bf-900e-4b4d19a2b086v1\fdve]8;;\]8;id=733803;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f241b93a-ce58-41bf-900e-4b4d19a2b086v1\-]8;;\
#            ]8;id=733803;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f241b93a-ce58-41bf-900e-4b4d19a2b086v1\f241b93a-ce58-41bf-900e-4b4d19a2b086v1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Estimated FlexCredit cost for sim_50_linear = 0.22
# Estimated FlexCredit cost for sim_50_quadratic = 0.22
# Estimated FlexCredit cost for sim_50_exponential = 0.22
# Estimated FlexCredit cost for sim_100_linear = 0.42
# Estimated FlexCredit cost for sim_100_quadratic = 0.42
# Estimated FlexCredit cost for sim_100_exponential = 0.42
# Total estimated FlexCredit cost for batch = 1.94

# %% [markdown]
# Run the batch and store all of the data in the `data_sweep` dir.

# %%
batch_sweep = batch.run(path_dir="data/data_sweep")
# Out:
# [10:45:48] Started working on Batch.                            ]8;id=407991;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:]8;id=336439;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py#475\475]8;;\
# [10:46:27] Maximum FlexCredit cost: 1.937 for the whole batch.  ]8;id=427101;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:]8;id=625409;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py#479\479]8;;\
#            Use 'Batch.real_cost()' to get the billed FlexCredit
#            cost after the Batch has completed.
# Output()
# [10:47:07] Batch complete.                                      ]8;id=663013;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:]8;id=703301;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py#522\522]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# Print the simulation log corresponding to the longest inverted taper to inspection.

# %%
print(batch_sweep["sim_100_quadratic"].log)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:47:09] loading SimulationData from                             ]8;id=878130;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=336425;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-d19b5467-c980-4fb4-bc99-e10392bdd7
#            73v1.hdf5
# Simulation domain Nx, Ny, Nz: [3477, 126, 136]
# Applied symmetries: (0, -1, 1)
# Number of computational grid points: 1.5829e+07.
# Using subpixel averaging: True
# Number of time steps: 8.9104e+04
# Automatic shutoff factor: 1.00e-05
# Time step (s): 5.3908e-17
#
#
# Compute source modes time (s):     0.2879
# Compute monitor modes time (s):    32.0110
# Rest of setup time (s):            9.0309
#
# Running solver for 89104 time steps...
# - Time step   2364 / time 1.27e-13s (  2 % done), field decay: 1.00e+00
# - Time step   3564 / time 1.92e-13s (  4 % done), field decay: 1.00e+00
# - Time step   7128 / time 3.84e-13s (  8 % done), field decay: 7.76e-01
# - Time step  10692 / time 5.76e-13s ( 12 % done), field decay: 5.40e-01
# - Time step  14256 / time 7.69e-13s ( 16 % done), field decay: 4.18e-01
# - Time step  17820 / time 9.61e-13s ( 20 % done), field decay: 3.55e-01
# - Time step  21384 / time 1.15e-12s ( 24 % done), field decay: 3.02e-01
# - Time step  24949 / time 1.34e-12s ( 28 % done), field decay: 1.31e-05
# - Time step  28513 / time 1.54e-12s ( 32 % done), field decay: 1.39e-07
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   30.9542
# Data write time (s):               0.0528

# %% [markdown]
# ### Parameter sweep results
#
# Now, we will get the batch results and plot the modal coupling efficiency at the central wavelength as a function of the inverted taper length.

# %%
coup_eff_tl = np.zeros((len(tap_names), len(taper_sweep) + 1))
for i in range(len(tap_names)):
    coup_eff_tl[i, 0] = power_tap_25[i].sel(f=freq_c)

sims = {
    f"sim_{tap_l}_{sim_name}": sim
    for sim_l, tap_l in zip(sim_sweep, taper_sweep)
    for sim, sim_name in zip(sim_l.values(), sim_l.keys())
}

for j, tl in enumerate(taper_sweep):
    for i, sn in enumerate(tap_names):
        data_sim = batch_sweep[f"sim_{tl}_{sn}"]
        mode_amps = data_sim["mode_0"]
        coeffs_f = mode_amps.amps.sel(direction="+", f=freq_c)
        power_0 = np.abs(coeffs_f.sel(mode_index=0)) ** 2
        power_0_db = 10 * np.log10(power_0)
        coup_eff_tl[i, j + 1] = power_0_db
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:47:10] loading SimulationData from                             ]8;id=238712;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=104472;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-e63eb20f-a799-4257-9dee-b157bdd6c5
#            97v1.hdf5
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:47:11] loading SimulationData from                             ]8;id=893798;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=926474;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-5e0478e3-9049-44b7-b1cd-353a381502
#            73v1.hdf5
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:47:22] loading SimulationData from                             ]8;id=680609;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=599575;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-1ea8dfac-9552-4028-a214-22dc3d4243
#            b9v1.hdf5
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:47:23] loading SimulationData from                             ]8;id=779359;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=560884;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-7bc37c92-8756-494d-8fce-7b6231adfb
#            d4v1.hdf5
# [10:47:24] loading SimulationData from                             ]8;id=428310;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=272930;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-d19b5467-c980-4fb4-bc99-e10392bdd7
#            73v1.hdf5
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            loading SimulationData from                             ]8;id=541534;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=345824;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-f241b93a-ce58-41bf-900e-4b4d19a2b0
#            86v1.hdf5

# %% [markdown]
# As shown below, the longer the taper, the higher the modal coupling efficiency, as is expected due to the increased adiabaticity. However, the quadratic shape profile seems more advantageous for this case as it achieved a steady state coupling loss of $\lt$ 0.6 dB for a 50 $\mu m$ taper length. In contrast, the exponential shape needs double this value, and an even longer taper length would be necessary for the linear profile to obtain similar coupling loss. Detailed discussions about the effects of taper profile over the coupling efficiency, bandwidth, footprint size, or taper/fiber misalignments can be found in the literature [[1](https://www.mdpi.com/2076-3417/10/4/1538),[2](https://opg.optica.org/prj/fulltext.cfm?uri=prj-7-2-201&id=404538),[3](https://www.sciencedirect.com/science/article/abs/pii/S0030401811006389)].

# %%
fig, ax = plt.subplots(1, figsize=(6, 3))
lin_style = ["ok", "sr", "hb"]
taper_lengths = [taper_l] + taper_sweep[:]
for ce, ls, lab in zip(coup_eff_tl, lin_style, tap_names):
    ax.plot(taper_lengths, ce, ls, label=lab)
ax.set_xlim([taper_lengths[0] - 2, taper_lengths[-1] + 2])
ax.set_xlabel("Taper Length ($\mu m$)")
ax.set_ylabel("Coupling Efficiency (dB)")
plt.legend()
plt.show()

# %% [markdown]
# Next, we will visualize the field distribution and the wavelength-dependent coupling coefficients for these longer inverted taper structures.

# %%
final_sim_data = [
    batch_sweep["sim_100_linear"],
    batch_sweep["sim_50_quadratic"],
    batch_sweep["sim_100_exponential"],
]

fig, axs = plt.subplots(3, 1, tight_layout=True, figsize=(10, 8))
for sim_data, tap_n, ax in zip(final_sim_data, tap_names, axs):
    sim_data.plot_field("field_xy", "Ey", f=freq_c, val="abs", ax=ax)
    ax.set_title(tap_n)
    ax.set_aspect("auto")  # Used to better visualize the shapes.
plt.show()
# Out:
# [10:47:25] loading SimulationData from                             ]8;id=566492;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=540603;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-7bc37c92-8756-494d-8fce-7b6231adfb
#            d4v1.hdf5
#            loading SimulationData from                             ]8;id=746776;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=643132;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-5e0478e3-9049-44b7-b1cd-353a381502
#            73v1.hdf5
#            loading SimulationData from                             ]8;id=716873;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=240924;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
#            data/data_sweep/fdve-f241b93a-ce58-41bf-900e-4b4d19a2b0
#            86v1.hdf5

# %%
plot_colors = ("black", "red", "blue")
fig, ax1 = plt.subplots(1, figsize=(8, 4))
for sim_data, color, label in zip(final_sim_data, plot_colors, tap_names):
    mode_amps = sim_data["mode_0"]
    coeffs_f = mode_amps.amps.sel(direction="+")
    power_0 = np.abs(coeffs_f.sel(mode_index=0)) ** 2
    power_0_db = 10 * np.log10(power_0)

    ax1.plot(
        wl_range,
        power_0_db,
        color=color,
        linestyle="solid",
        linewidth=1.0,
        label=label,
    )
ax1.set_xlim([wl_range[0], wl_range[-1]])
ax1.set_xlabel("Wavelength (um)")
ax1.set_ylabel("Power (dB)")
ax1.set_title("Coupling Efficiency")
plt.legend()
plt.show()
