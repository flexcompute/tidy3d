# %% [markdown]
# # Waveguide crossing based on cosine tapers

# %% [markdown]
# To achieve a high integration density on a photonic chip, efficient routing of light with low loss using compact junctions is necessary. Therefore, waveguide crossings are crucial building blocks in high performance integrated circuits.
#
# This example model demonstrates the simulation of a waveguide crossing based on cosine tapers. The convex cosine taper focuses the guided mode at the center of the crossing junction. This ensures the light is efficiently transmitted into the through port instead of scattered into the cross ports. The device achieves an insertion loss of ~0.2 dB and crosstalk ~-30 dB in the O-band (1260 nm -1360 nm). The design is adapted from [Sujith Chandran, et al. "Beam shaping for ultra-compact waveguide crossings on monolithic silicon photonics platform," Opt. Lett. 45, 6230-6233 (2020)](https://opg.optica.org/ol/abstract.cfm?uri=ol-45-22-6230).
#
# <img src="img/waveguide_crossing.png" width=600 alt="Schematic of the waveguide crossing">
#
# If you are new to the finite-difference time-domain (FDTD) method, we highly recommend going through our [FDTD101](https://www.flexcompute.com/fdtd101/) tutorials.

# %%
import numpy as np
import matplotlib.pyplot as plt

import tidy3d as td
import tidy3d.web as web
from scipy.optimize import fsolve

# %% [markdown]
# ## Simulation Setup

# %% [markdown]
# Define geometric parameters and materials. In this device, the Si waveguide has a thickness of 161 nm and a width of 350 nm.

# %%
h = 0.161  # waveguide thickness
w_in = 0.35  # input taper width
w_out = 1.1  # output taper width
w_m = 0.75  # amplitude of the cos function
l_t = 5.3  # taper length
inf_eff = (
    1000  # effective infinity used to make sure the waveguides extend into the pml
)

# %%
si = td.Medium(permittivity=3.67**2)
sio2 = td.Medium(permittivity=1.45**2)

# %% [markdown]
# The taper width is described by a cosine function $w(x)=w_m cos(ax+b)$. To determine the parameters $a$ and $b$, we solve a system of equations to ensure $w(x)=w_{in}/2$ at the beginning of the taper and $w(x)=w_{out}/2$ at the end of the taper. This can be easily done using fsolve from Scipy.
#
# After we obtain $w(x)$, vertices can be generated and the taper can be made using PolySlab. Once the first taper is made, the rest three tapers can be made by manipulating the vertices with the symmetry relation.

# %%
# numerically solve for the cos function that describes the taper shape
def equations(x0):
    a, b = x0
    return (
        w_m * np.cos(a * (-w_out / 2) + b) - w_out / 2,
        w_m * np.cos(a * (-w_out / 2 - l_t) + b) - w_in / 2,
    )


a, b = fsolve(equations, (0.5, 2))

x = np.linspace(-w_out / 2 - l_t, -w_out / 2, 30)
w = w_m * np.cos(a * x + b)

# using the calculated taper shape to construct the taper as a PolySlab
vertices = np.zeros((2 * len(x), 2))
vertices[:, 0] = np.concatenate((x, np.flipud(x)))
vertices[:, 1] = np.concatenate((w, -np.flipud(w)))
taper_1 = td.Structure(
    geometry=td.PolySlab(vertices=vertices, axis=2, slab_bounds=(-h / 2, h / 2)),
    medium=si,
)

# creating the other four tapers by manipulating the vertices of the first taper
vertices[:, 0] = -vertices[:, 0]
taper_2 = td.Structure(
    geometry=td.PolySlab(vertices=vertices, axis=2, slab_bounds=(-h / 2, h / 2)),
    medium=si,
)

vertices[:, [1, 0]] = vertices[:, [0, 1]]
taper_3 = td.Structure(
    geometry=td.PolySlab(vertices=vertices, axis=2, slab_bounds=(-h / 2, h / 2)),
    medium=si,
)

vertices[:, 1] = -vertices[:, 1]
taper_4 = td.Structure(
    geometry=td.PolySlab(vertices=vertices, axis=2, slab_bounds=(-h / 2, h / 2)),
    medium=si,
)

# creating the center crossing junction using a Box
corner = 0
center = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-w_out / 2 - corner, -w_out / 2 - corner, -h / 2),
        rmax=(w_out / 2 + corner, w_out / 2 + corner, h / 2),
    ),
    medium=si,
)

# creating the input port and through port
horizontal_wg = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-inf_eff, -w_in / 2, -h / 2), rmax=(inf_eff, w_in / 2, h / 2)
    ),
    medium=si,
)

# creating the cross ports
vertical_wg = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-w_in / 2, -inf_eff, -h / 2), rmax=(w_in / 2, inf_eff, h / 2)
    ),
    medium=si,
)

# %% [markdown]
# Set up simulation domain, source, and monitors. A mode source is used to excite the input waveguide. A field monitor at $z=0$ plane is added to monitor the field propagation. Two flux monitors are added at the through port and cross port to monitor the transmission and crosstalk levels.
#
# Before running the simulation, we can use the plot method to ensure the geometry, source, and monitors are set up correctly.

# %%
lda0 = 1.31  # central wavelength
freq0 = td.C_0 / lda0  # operation frequency
ldas = np.linspace(1.26, 1.36, 101)  # wavelength range of interest
freqs = td.C_0 / ldas  # frequency range of interest

l_wg = 1  # input/output waveguide length
Lx = 2 * l_t + w_out + 2 * l_wg
Ly = 2 * l_t + w_out + 2 * l_wg
Lz = 1.5 * lda0
sim_size = (Lx, Ly, Lz)

# define a mode source for excitation using the lowest order mode
mode_source = td.ModeSource(
    center=(-Lx / 2 + l_wg / 2, 0, 0),
    size=(0, 4 * w_in, 4 * h),
    source_time=td.GaussianPulse(freq0=freq0, fwidth=freq0 / 10),
    direction="+",
    mode_spec=td.ModeSpec(num_modes=1, target_neff=3.455, filter_pol="te"),
    mode_index=0,
)

# add a field monitor at z=0 for field visualization
field_monitor = td.FieldMonitor(
    center=(0, 0, 0), size=(td.inf, td.inf, 0), freqs=[freq0], name="field"
)

# define a flux monitor to detect transmission to the through port
flux_monitor_through = td.FluxMonitor(
    center=(Lx / 2 - l_wg / 2, 0, 0),
    size=(0, 4 * w_in, 4 * h),
    freqs=freqs,
    name="flux_through",
)

# define a flux monitor to detect transmission to the cross port
flux_monitor_cross = td.FluxMonitor(
    center=(0, Ly / 2 - l_wg / 2, 0),
    size=(4 * w_in, 0, 4 * h),
    freqs=freqs,
    name="flux_cross",
)

sim = td.Simulation(
    center=(0, 0, 0),
    size=sim_size,
    grid_spec=td.GridSpec.auto(min_steps_per_wvl=20, wavelength=lda0),
    structures=[taper_1, taper_2, taper_3, taper_4, center, horizontal_wg, vertical_wg],
    sources=[mode_source],
    monitors=[field_monitor, flux_monitor_through, flux_monitor_cross],
    run_time=1e-12,
    boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),
    medium=sio2,
)

sim.plot(z=0)
plt.show()
# Out:
# <<<<<<< local
# [18:32:08] WARNING: Default value for the field monitor           ]8;id=893463;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py\monitor.py]8;;\:]8;id=670788;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/components/monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
# =======
# [12:54:38] WARNING: Default value for the field monitor           ]8;id=587351;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\components\monitor.py\monitor.py]8;;\:]8;id=546230;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\components\monitor.py#261\261]8;;\
#            'colocate' setting has changed to 'True' in Tidy3D
#            2.4.0. All field components will be colocated to the
#            grid boundaries. Set to 'False' to get the raw fields
#            on the Yee grid instead.
# >>>>>>> remote

# %% [markdown]
# To have a better visualization, we can also plot the simulation in 3D.

# %%
sim.plot_3d()
# Out:
#     <iframe id="simulation-viewer169280967911767763" src=https://feature-simulation-viewer.d3a9gfg7glllfq.amplifyapp.com/simulation-viewer?uuid=169280967911767763 width="800" height="800" allowfullscreen="true"></iframe>
#     <script>
#
#     window.postMessageToViewer169280967911767763 = event => {
#         if(event.data.type === 'viewer'&&event.data.uuid==='169280967911767763'){
#             document.getElementById('simulation-viewer169280967911767763').contentWindow.postMessage({ type: 'jupyter', uuid:'169280967911767763', value:{
#     "type": "Simulation",
#     "center": [
#         0.0,
#         0.0,
#         0.0
#     ],
#     "size": [
#         13.7,
#         13.7,
#         1.965
#     ],
#     "run_time": 1e-12,
#     "medium": {
#         "name": null,
#         "frequency_range": null,
#         "allow_gain": false,
#         "nonlinear_spec": null,
#         "type": "Medium",
#         "permittivity": 2.1025,
#         "conductivity": 0.0
#     },
#     "symmetry": [
#         0,
#         0,
#         0
#     ],
#     "structures": [
#         {
#             "geometry": {
#                 "type": "PolySlab",
#                 "axis": 2,
#                 "sidewall_angle": 0.0,
#                 "reference_plane": "middle",
#                 "slab_bounds": [
#                     -0.0805,
#                     0.0805
#                 ],
#                 "dilation": 0.0,
#                 "vertices": [
#                     [
#                         -5.85,
#                         0.17500000000510962
#                     ],
#                     [
#                         -5.667241379310345,
#                         0.2268843734432524
#                     ],
#                     [
#                         -5.48448275862069,
#                         0.27759884645112975
#                     ],
#                     [
#                         -5.301724137931034,
#                         0.3268819162954677
#                     ],
#                     [
#                         -5.118965517241379,
#                         0.37447946109144536
#                     ],
#                     [
#                         -4.936206896551724,
#                         0.4201460501498916
#                     ],
#                     [
#                         -4.753448275862069,
#                         0.4636462095094338
#                     ],
#                     [
#                         -4.570689655172414,
#                         0.5047556361280466
#                     ],
#                     [
#                         -4.387931034482758,
#                         0.5432623544731751
#                     ],
#                     [
#                         -4.205172413793103,
#                         0.578967809546621
#                     ],
#                     [
#                         -4.022413793103448,
#                         0.6116878907081529
#                     ],
#                     [
#                         -3.8396551724137926,
#                         0.6412538810186169
#                     ],
#                     [
#                         -3.6568965517241376,
#                         0.6675133272073865
#                     ],
#                     [
#                         -3.474137931034482,
#                         0.6903308257782732
#                     ],
#                     [
#                         -3.2913793103448272,
#                         0.7095887212004419
#                     ],
#                     [
#                         -3.108620689655172,
#                         0.7251877125841993
#                     ],
#                     [
#                         -2.925862068965517,
#                         0.7370473657134087
#                     ],
#                     [
#                         -2.743103448275862,
#                         0.7451065277943009
#                     ],
#                     [
#                         -2.5603448275862064,
#                         0.7493236427820811
#                     ],
#                     [
#                         -2.3775862068965514,
#                         0.7496769656593919
#                     ],
#                     [
#                         -2.194827586206896,
#                         0.7461646745617304
#                     ],
#                     [
#                         -2.012068965517241,
#                         0.7388048801716618
#                     ],
#                     [
#                         -1.8293103448275856,
#                         0.727635532333386
#                     ],
#                     [
#                         -1.6465517241379306,
#                         0.7127142243691909
#                     ],
#                     [
#                         -1.4637931034482756,
#                         0.6941178961068066
#                     ],
#                     [
#                         -1.2810344827586206,
#                         0.6719424371489653
#                     ],
#                     [
#                         -1.0982758620689648,
#                         0.6463021924308527
#                     ],
#                     [
#                         -0.9155172413793098,
#                         0.6173293726149868
#                     ],
#                     [
#                         -0.7327586206896548,
#                         0.5851733723637418
#                     ],
#                     [
#                         -0.55,
#                         0.5500000000047635
#                     ],
#                     [
#                         -0.55,
#                         -0.5500000000047635
#                     ],
#                     [
#                         -0.7327586206896548,
#                         -0.5851733723637418
#                     ],
#                     [
#                         -0.9155172413793098,
#                         -0.6173293726149868
#                     ],
#                     [
#                         -1.0982758620689648,
#                         -0.6463021924308527
#                     ],
#                     [
#                         -1.2810344827586206,
#                         -0.6719424371489653
#                     ],
#                     [
#                         -1.4637931034482756,
#                         -0.6941178961068066
#                     ],
#                     [
#                         -1.6465517241379306,
#                         -0.7127142243691909
#                     ],
#                     [
#                         -1.8293103448275856,
#                         -0.727635532333386
#                     ],
#                     [
#                         -2.012068965517241,
#                         -0.7388048801716618
#                     ],
#                     [
#                         -2.194827586206896,
#                         -0.7461646745617304
#                     ],
#                     [
#                         -2.3775862068965514,
#                         -0.7496769656593919
#                     ],
#                     [
#                         -2.5603448275862064,
#                         -0.7493236427820811
#                     ],
#                     [
#                         -2.743103448275862,
#                         -0.7451065277943009
#                     ],
#                     [
#                         -2.925862068965517,
#                         -0.7370473657134087
#                     ],
#                     [
#                         -3.108620689655172,
#                         -0.7251877125841993
#                     ],
#                     [
#                         -3.2913793103448272,
#                         -0.7095887212004419
#                     ],
#                     [
#                         -3.474137931034482,
#                         -0.6903308257782732
#                     ],
#                     [
#                         -3.6568965517241376,
#                         -0.6675133272073865
#                     ],
#                     [
#                         -3.8396551724137926,
#                         -0.6412538810186169
#                     ],
#                     [
#                         -4.022413793103448,
#                         -0.6116878907081529
#                     ],
#                     [

# %% [markdown]
# Once the simulation set up is verified, submit job to the server. Before running the simulation, we can get a cost estimation using `estimate_cost`. This prevents us from accidentally running large jobs that we set up by mistake. The estimated cost is the maximum cost corresponding to running all the time steps.

# %%
job = web.Job(simulation=sim, task_name="waveguide_crossing", verbose=True)
estimated_cost = web.estimate_cost(job.task_id)

print(f'The estimated maximum cost is {estimated_cost:.3f} Flex Credits.')
# Out:
# <<<<<<< local
#            Created task 'waveguide_crossing' with task_id          ]8;id=317872;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=854638;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#188\188]8;;\
#            'fdve-c7430dda-654c-4bef-8c18-b1cab962cba9v1'.
#            View task using web UI at                               ]8;id=996104;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=367647;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#190\190]8;;\
#            ]8;id=744945;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c7430dda-654c-4bef-8c18-b1cab962cba9v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=585151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c7430dda-654c-4bef-8c18-b1cab962cba9v1\taskId]8;;\]8;id=744945;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c7430dda-654c-4bef-8c18-b1cab962cba9v1\=]8;;\]8;id=486309;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c7430dda-654c-4bef-8c18-b1cab962cba9v1\fdve]8;;\]8;id=744945;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c7430dda-654c-4bef-8c18-b1cab962cba9v1\-]8;;\
#            ]8;id=744945;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c7430dda-654c-4bef-8c18-b1cab962cba9v1\c7430dda-654c-4bef-8c18-b1cab962cba9v1']8;;\.
# Output()
# =======
# >>>>>>> remote
# <<<<<<< local <removed>
# =======
# [12:54:39] Created task 'waveguide_crossing' with task_id          ]8;id=535886;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=942865;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#188\188]8;;\
#            'fdve-a45f3e23-6504-4bf8-8ae6-9537d04b4190v1'.
# >>>>>>> remote <modified: text/html, text/plain>
# <<<<<<< local <removed>
# =======
#            View task using web UI at                               ]8;id=545007;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=360396;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#190\190]8;;\
#            ]8;id=803971;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a45f3e23-6504-4bf8-8ae6-9537d04b4190v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=990113;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a45f3e23-6504-4bf8-8ae6-9537d04b4190v1\taskId]8;;\]8;id=803971;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a45f3e23-6504-4bf8-8ae6-9537d04b4190v1\=]8;;\]8;id=517119;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a45f3e23-6504-4bf8-8ae6-9537d04b4190v1\fdve]8;;\]8;id=803971;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a45f3e23-6504-4bf8-8ae6-9537d04b4190v1\-]8;;\
#            ]8;id=803971;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a45f3e23-6504-4bf8-8ae6-9537d04b4190v1\a45f3e23-6504-4bf8-8ae6-9537d04b4190v1']8;;\.
# >>>>>>> remote <modified: text/html, text/plain>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The estimated maximum cost is 0.488 Flex Credits.

# %% [markdown]
# The cost is reasonaly so we can run the simulation.

# %%
sim_data = job.run(path="data/simulation_data.hdf5")
# Out:
# <<<<<<< local
# [18:32:15] status = queued                                         ]8;id=370358;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=594201;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#361\361]8;;\
# Output()
# [18:32:31] status = preprocess                                     ]8;id=118939;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=217425;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#355\355]8;;\
# =======
# >>>>>>> remote
# <<<<<<< local <removed>
# =======
# [12:55:00] status = queued                                         ]8;id=551514;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=366156;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#361\361]8;;\
# >>>>>>> remote <modified: text/html, text/plain>
# <<<<<<< local <removed>
# =======
# [12:55:03] status = preprocess                                     ]8;id=674525;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=695648;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#355\355]8;;\
# >>>>>>> remote <modified: text/html, text/plain>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <<<<<<< local
# [18:32:35] Maximum FlexCredit cost: 0.488. Use                     ]8;id=353532;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=514235;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#341\341]8;;\
#            'web.real_cost(task_id)' to get the billed FlexCredit
#            cost after a simulation run.
#            starting up solver                                      ]8;id=314981;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=354168;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#377\377]8;;\
#            running solver                                          ]8;id=156859;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=949219;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#386\386]8;;\
#            To cancel the simulation, use 'web.abort(task_id)' or   ]8;id=614849;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=78084;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#387\387]8;;\
#            'web.delete(task_id)' or abort/delete the task in the
#            web UI. Terminating the Python script will not stop the
#            job running on the cloud.
# Output()
# [18:33:06] early shutoff detected, exiting.                        ]8;id=586035;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=848823;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#404\404]8;;\
# =======
# [12:55:08] Maximum FlexCredit cost: 0.488. Use                     ]8;id=71341;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=405862;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#341\341]8;;\
#            'web.real_cost(task_id)' to get the billed FlexCredit
#            cost after a simulation run.
# >>>>>>> remote
# <<<<<<< local <removed>
# =======
#            starting up solver                                      ]8;id=261725;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=71778;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#377\377]8;;\
# >>>>>>> remote <modified: text/html, text/plain>
# <<<<<<< local <removed>
# =======
#            running solver                                          ]8;id=833974;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=481854;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#386\386]8;;\
# >>>>>>> remote <modified: text/html, text/plain>
#            To cancel the simulation, use 'web.abort(task_id)' or   ]8;id=442240;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=971214;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#387\387]8;;\
#            'web.delete(task_id)' or abort/delete the task in the
#            web UI. Terminating the Python script will not stop the
#            job running on the cloud.
# Output()
# <<<<<<< local <removed>
# =======
# [12:55:39] early shutoff detected, exiting.                        ]8;id=20853;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=793996;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#404\404]8;;\
# >>>>>>> remote <modified: text/html, text/plain>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <<<<<<< local
#            status = postprocess                                    ]8;id=599944;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=215710;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#419\419]8;;\
# Output()
# [18:33:11] status = success                                        ]8;id=73386;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=78320;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#426\426]8;;\
# =======
# >>>>>>> remote
# <<<<<<< local <removed>
# =======
#            status = postprocess                                    ]8;id=513249;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=82853;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#419\419]8;;\
# >>>>>>> remote <modified: text/html, text/plain>
# <<<<<<< local <removed>
# =======
# [12:55:44] status = success                                        ]8;id=673453;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=135217;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#426\426]8;;\
# >>>>>>> remote <modified: text/html, text/plain>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <<<<<<< local
# Output()
# =======
# Output()
# >>>>>>> remote
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <<<<<<< local
# [18:33:13] loading SimulationData from data/simulation_data.hdf5   ]8;id=236428;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:]8;id=98587;file:///home/momchil/Drive/flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py#590\590]8;;\
# =======
# >>>>>>> remote
# <<<<<<< local <removed>
# =======
# [12:55:47] loading SimulationData from data/simulation_data.hdf5   ]8;id=273863;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=597200;file://C:\Users\xinzhong\Desktop\tidy3d\tidy3d\web\webapi.py#590\590]8;;\
# >>>>>>> remote <modified: text/html, text/plain>

# %% [markdown]
# ## Result Visualization

# %% [markdown]
# After the simulation is complete, first plot the field intensity distribution.
#
# From the figure below, a good transmission to the through port is observed. In the crossing junction, a strong field focus is formed due to the focusing property of the cosine taper.

# %%
sim_data.plot_field(
    field_monitor_name="field", field_name="E", val="abs^2", f=freq0, vmin=0, vmax=3000
)
plt.show()
# Out:
# <<<<<<< local
# =======
# >>>>>>> remote

# %% [markdown]
# Finally, to quantify the designed waveguide crossing's performance, plot insertion loss and crosstalk level.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))

T_through = sim_data["flux_through"].flux
T_cross = sim_data["flux_cross"].flux

ax1.plot(ldas, 10 * np.log10(T_through))
ax1.set_xlabel("Wavelength ($\mu m$)")
ax1.set_ylabel("Insertion loss (dB)")
ax1.set_ylim((-0.3, 0))

ax2.plot(ldas, 10 * np.log10(T_cross/T_through))
ax2.set_xlabel("Wavelength ($\mu m$)")
ax2.set_ylabel("Crosstalk (dB)")
ax2.set_ylim((-30, -25))
plt.show()
# Out:
# <<<<<<< local
# =======
# >>>>>>> remote
