# %% [markdown]
# # MMI 1 x 4 power splitter

# %% [markdown]
# Run this notebook in your browser using [Binder](https://mybinder.org/v2/gh/flexcompute-readthedocs/tidy3d-docs/readthedocs?labpath=docs%2Fsource%2Fnotebooks%2FMMI_1by4.ipynb).
#
# Optical power splitters are essential components in integrated photonics. Power splitters based on multimode interference (MMI) device are easy to fabricate and can achieve low excess loss as well as large bandwidth. Although the design of a MMI power splitter is based on the self-imaging principle, fine-tuning the geometric parameters with accurate and fast numerical simulations is crucial to achieving optimal device performance.
#
# This example aims to demonstrate the design and optimization of 1 to 4 MMI device at telecom wavelength for power splitting applications. The initial design is adapted from [D. Malka, Y. Danan, Y. Ramon, Z. Zalevsky, A Photonic 1 x 4 Power Splitter Based on Multimode Interference in Silicon–Gallium-Nitride Slot Waveguide Structures. Materials. 9, 516 (2016)](https://www.mdpi.com/1996-1944/9/7/516).
#
# The device uses a Si-GaN-Si slot waveguide strcuture as schematically shown below.
#
# <img src="img/mmi_schematic.png" width="500" height="500">

# %% [markdown]
# ## Simulation Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import tidy3d as td
import tidy3d.web as web
from tidy3d.plugins import ModeSolver
# Out:
# [17:59:46] INFO     Using client version: 1.8.0                                                     ]8;id=705114;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\__init__.py\__init__.py]8;;\:]8;id=908841;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\__init__.py#107\107]8;;\

# %% [markdown]
# Define materials. There are three materials involved in this model. The SiO2 cladding and the Si waveguide with GaN slot. All materials are modeled as lossless and dispersionless in this particular case.

# %%
si = td.Medium(permittivity = 3.48**2)
gan = td.Medium(permittivity = 2.305**2)
sio2 = td.Medium(permittivity = 1.444**2)

# %% [markdown]
# Define initial design parameters and wrap simulation setup in a function. The arguments of the function are the paremeters we want to optimize later. In this example, we aim to optimize the length and width of the MMI section.

# %%
W_MMI = 5 #width of the MMI section
L_MMI = 11.2  #length of the MMI section
g1 = 0.9  #gap between the output waveguides
W1 = 0.4  #width of the waveguide
W2 = 0.8  #width of the tapper
L1 = 2  #length of the input tapper
L2 = 5  #length of the output tapper
H_Si = 0.3   #thickness of the Si layer
H_GaN = 0.1  #thickness of the GaN layer
g3 = (W2-W1)/2   #auxilary parameter defined for easier geometry building
g2 = g1 - 2*g3  #gap between the output tapers
lda0 = 1.55   #central wavelength
freq0 = td.C_0/lda0  #central frequency
ldas = np.linspace(1.45,1.65,101)   #wavelength range
freqs = td.C_0/ldas  #frequency range

#buffer spacings in the x and y directions.
buffer_x = 1
buffer_y = 1.5

#define a function that takes the geometric parameters as input arguments and return a Simulation object
def make_sim(L_MMI, W_MMI):
    #the whole device is defined as a PolySlab with vertices given by the following
    vertices = np.array([ (-W1/2, -100),
                          (-W1/2, 0),
                          (-W2/2, L1),
                          (-W_MMI/2, L1),
                          (-W_MMI/2, L1+L_MMI),
                          (-g2/2-W2-g2-2*g3-W1, L1+L_MMI),
                          (-g2/2-W2-g2-g3-W1, L1+L_MMI+L2),
                          (-g2/2-W2-g2-g3-W1, 100),
                          (-g2/2-W2-g2-g3, 100),
                          (-g2/2-W2-g2-g3, L1+L_MMI+L2),
                          (-g2/2-W2-g2, L1+L_MMI),
                          (-g2/2-W2, L1+L_MMI),
                          (-g1/2-W1, L1+L_MMI+L2),
                          (-g1/2-W1, 100),
                          (-g1/2, 100),
                          (-g1/2, L1+L_MMI+L2),
                          (-g2/2, L1+L_MMI),
                          (g2/2, L1+L_MMI),
                          (g1/2, L1+L_MMI+L2),
                          (g1/2, 100),
                          (g1/2+W1, 100),
                          (g1/2+W1, L1+L_MMI+L2),
                          (g2/2+W2, L1+L_MMI),
                          (g2/2+W2+g2, L1+L_MMI),
                          (g2/2+W2+g2+g3, L1+L_MMI+L2),
                          (g1/2+W1+g1, 100),
                          (g1/2+W1+g1+W1, 100),
                          (g2/2+W2+g2+g3+W1, L1+L_MMI+L2),
                          (g2/2+W2+g2+2*g3+W1, L1+L_MMI),
                          (W_MMI/2, L1+L_MMI),
                          (W_MMI/2, L1),
                          (W2/2, L1),
                          (W1/2, 0),  
                          (W1/2, -100),
                         ])

    mmi_layer1 = td.Structure(geometry=td.PolySlab(vertices=vertices, axis=2,slab_bounds=(-H_Si-0.5*H_GaN, H_Si+0.5*H_GaN)), medium=si)
    mmi_layer2 = td.Structure(geometry=td.PolySlab(vertices=vertices, axis=2,slab_bounds=(-0.5*H_GaN, 0.5*H_GaN)), medium=gan)
        
    #simulation domain size
    Lx = W_MMI+2*buffer_x
    Ly = L1+L_MMI+L2+2*buffer_y
    Lz = 5*(H_GaN*2+H_Si)
    sim_size = (Lx, Ly, Lz)

    mode_spec = td.ModeSpec(num_modes=5, target_neff=3)
    
    #add a mode source for excitation
    mode_source = td.ModeSource(
        center=(0, -buffer_y/3, 0),
        size=(3*W1, 0, 3*(H_GaN*2+H_Si)),
        source_time = td.GaussianPulse(
            freq0=freq0,
            fwidth=freq0/10),
        direction='+',
        mode_spec=mode_spec,
        mode_index=0)
    
    #add two flux monitors to monitor the transmission power at output waveguides
    flux_monitor1 = td.FluxMonitor(
        center = ((g1+W1)/2,Ly-buffer_y,0),
        size = (2*W1, 0, 2*W1),
        freqs = freqs,
        name='flux1')    

    flux_monitor2 = td.FluxMonitor(
        center = (3*(g1+W1)/2,Ly-buffer_y,0),
        size = (2*W1, 0, 2*W1),
        freqs = freqs,
        name='flux2')  
    
    #add two mode monitor to monitor the mode profiles at output waveguides
    mode_monitor1 = td.ModeMonitor(
        center = ((g1+W1)/2,Ly-buffer_y,0),
        size = (2*W1, 0, 2*W1),
        freqs = freqs,
        mode_spec=mode_spec,
        name='mode1')        
    
    mode_monitor2 = td.ModeMonitor(
        center = (3*(g1+W1)/2,Ly-buffer_y,0),
        size = (2*W1, 0, 2*W1),
        freqs = freqs,
        mode_spec=mode_spec,
        name='mode2')    
    
    #add a field monitor to monitor the field distribution
    field_monitor = td.FieldMonitor(
        center = (0,0,0),
        size = (td.inf, td.inf, 0),
        freqs = [freq0],
        name='field'
    )

    sim = td.Simulation(
            center=(0,Ly/2-buffer_y/2,0),
            size=sim_size,
            grid_spec=td.GridSpec.auto(min_steps_per_wvl=20, wavelength=td.C_0/freq0),
            structures=[mmi_layer1, mmi_layer2],
            sources=[mode_source],
            monitors=[field_monitor, flux_monitor1, flux_monitor2, mode_monitor1, mode_monitor2],
            run_time=1e-11,
            boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),
            medium=sio2)    
    return sim

# %% [markdown]
# ## Initial Design

# %% [markdown]
# First, we simulate an initial design using the previously defined design parameters.

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
sim = make_sim(L_MMI, W_MMI)
sim.plot(z=0, ax=ax1)
sim.plot(y=-buffer_y/3, ax=ax2)

# %% [markdown]
# Before simulation, let's inspect the waveguide modes supported in the slot waveguide to make sure we are using the correct excitation source.

# %%
mode_spec = td.ModeSpec(num_modes=5, target_neff=3)
mode_solver = ModeSolver(
    simulation=sim,
    plane=td.Box(center=(0, -buffer_y/3, 0), size=(3*W1, 0, 3*(H_GaN*2+H_Si))),
    mode_spec=mode_spec,
    freqs=[freq0],
)
mode_data = mode_solver.solve()

# %% [markdown]
# The lowest order mode shows a strong field confinement between the Si area. This is the mode we want to use as excitation.

# %%
mode_index=0

f, (ax1, ax2, ax3) = plt.subplots(1, 3, tight_layout=True, figsize=(10, 3))
abs(mode_data.Ex.isel(mode_index=mode_index)).plot(x='x', y='z', ax=ax1, cmap="magma")
abs(mode_data.Ey.isel(mode_index=mode_index)).plot(x='x', y='z', ax=ax2, cmap="magma")
abs(mode_data.Ez.isel(mode_index=mode_index)).plot(x='x', y='z', ax=ax3, cmap='magma')

ax1.set_title('|Ex(x, y)|')
ax1.set_aspect("equal")
ax2.set_title('|Ey(x, y)|')
ax2.set_aspect("equal")
ax3.set_title('|Ez(x, y)|')
ax3.set_aspect("equal")
plt.show()

# %% [markdown]
# Submit simulation job to the server.

# %%
job = web.Job(simulation=sim, task_name='mmi')
sim_data = job.run(path='data/simulation_data.hdf5')
# Out:
# [17:59:49] INFO     Using Tidy3D credentials from stored file.                                           ]8;id=390301;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\auth.py\auth.py]8;;\:]8;id=303056;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\auth.py#70\70]8;;\
# [17:59:51] INFO     Authentication successful.                                                           ]8;id=113639;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\auth.py\auth.py]8;;\:]8;id=106027;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\auth.py#30\30]8;;\
#            INFO     Uploaded task 'mmi' with task_id '5604c53a-c304-4a14-a8a3-a768b35ad162'.          ]8;id=812367;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=311099;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [17:59:54] INFO     status = queued                                                                   ]8;id=437253;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=404946;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#264\264]8;;\
# Output()
# [18:00:03] INFO     Maximum flex unit cost: 1.96                                                      ]8;id=893174;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=23723;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#255\255]8;;\
#            INFO     status = preprocess                                                               ]8;id=57334;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=701935;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#276\276]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [18:00:07] INFO     starting up solver                                                                ]8;id=660067;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=826836;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#280\280]8;;\
# [18:00:18] INFO     running solver                                                                    ]8;id=173346;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=520213;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#286\286]8;;\
# Output()
# [18:05:50] INFO     early shutoff detected, exiting.                                                  ]8;id=723582;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=298347;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#297\297]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            INFO     status = postprocess                                                              ]8;id=239737;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=675998;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#303\303]8;;\
# Output()
# [18:05:57] INFO     status = success                                                                  ]8;id=895253;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=374714;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#309\309]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [18:05:58] INFO     downloading file "output/monitor_data.hdf5" to "data/simulation_data.hdf5"        ]8;id=817690;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=602609;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:00] INFO     loading SimulationData from data/simulation_data.hdf5                             ]8;id=381458;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=890367;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\

# %% [markdown]
# Visualize the field distribution.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,8))
sim_data.plot_field('field', 'int', ax = ax1, f=freq0)
sim_data.plot_field('field', 'Ez', ax = ax2, f=freq0)

# %% [markdown]
# Plot transmission on each output waveguide as well as the total excess loss. At the central wavelength of 1550 nm, the transimission power at the inner waveguide and outer waveguide differs by about 1%. The excess loss is about 0.4 dB.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))
T1 = sim_data['flux1'].flux
T2 = sim_data['flux2'].flux

plt.sca(ax1)
plt.plot(ldas, T1, ldas, T2)
plt.vlines(x=1.55, ymin=0.1, ymax=0.3, colors='black', ls='--')
plt.xlabel('Wavelength ($\mu m$)')
plt.ylabel('Transmission to output waveguide')
plt.legend(('Inner waveguide', 'Outer waveguide'))

plt.sca(ax2)
excess_loss = -10*np.log10(2*(T1+T2))
plt.plot(ldas, excess_loss)
plt.vlines(x=1.55, ymin=0, ymax=1, colors='black', ls='--')
plt.hlines(y=excess_loss[50], xmin=1.45, xmax=1.65, colors='black', ls='--')
plt.xlabel('Wavelength ($\mu m$)')
plt.ylabel('Excess loss (dB)')

# %% [markdown]
# We can use the mode monitor to inspect the composition of each mode at the output. For the inner waveguide, we can see that the fundamental mode is dominant and a small amount of Mode 4 is excited.

# %%
mode_amp = sim_data['mode1'].amps.sel(direction="+")
mode_power = np.abs(mode_amp)**2/T1
plt.plot(ldas, mode_power)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power share (%)')
plt.legend(["Mode 0", "Mode 1", "Mode 2", "Mode 3", "Mode 4"])

# %% [markdown]
# ## Optimization

# %% [markdown]
# Further tuning of the geometric parameters is likely to improve the device's performance further. We will perform a parameter sweep on two parameters to see if we can optimize the MMI. The goal is to achieve even power splitting among output waveguides while keeping the excess loss low.
#
# The length of the MMI is swept from 11.1 to 11.2 $\mu m$ in 50 nm step and the width from 4.8 to 5 $\mu m$ in 100 nm step. This results in a total of 9 simulations. Since this is just a demonstration model, we limit the total number of simulations for the sake of time. In practice, one can perform much larger parameter sweeps to cover a larger parameter space.

# %%
L_MMIs = np.linspace(11.1, 11.2, 3)  #MMI length varies from 11.1 to 11.2 um
W_MMIs = np.linspace(4.8, 5, 3)  #MMI width varies from 4.8 to 5 um

sims = {f'L_MMI={L_MMI:.2f};W_MMI={W_MMI:.2f}' : make_sim(L_MMI, W_MMI) for L_MMI in L_MMIs for W_MMI in W_MMIs}
batch = web.Batch(simulations=sims)
batch_results = batch.run(path_dir='data')
# Out:
# [18:06:06] INFO     Uploaded task 'L_MMI=11.10;W_MMI=4.80' with task_id                               ]8;id=874940;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=151512;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     '22529759-6b8e-48ee-a2b1-eb8ba8179251'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:08] INFO     Uploaded task 'L_MMI=11.10;W_MMI=4.90' with task_id                               ]8;id=198091;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=32605;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     '161dd6fd-3e35-4c1c-baed-4f7791a4183f'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:09] INFO     Uploaded task 'L_MMI=11.10;W_MMI=5.00' with task_id                               ]8;id=883254;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=626700;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     'afabd316-98b4-4daf-ae84-210ca781b932'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:11] INFO     Uploaded task 'L_MMI=11.15;W_MMI=4.80' with task_id                               ]8;id=31027;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=514153;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     '82a2e1c6-fd1d-4fce-a4e9-e6ab22ba92d7'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:13] INFO     Uploaded task 'L_MMI=11.15;W_MMI=4.90' with task_id                               ]8;id=434986;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=819710;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     '3b3fbbd3-2f4c-461d-9ded-e35287ae22b8'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:16] INFO     Uploaded task 'L_MMI=11.15;W_MMI=5.00' with task_id                               ]8;id=624921;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=5886;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     'ac756e70-09df-4c3d-b8f2-cc2bfa737492'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:18] INFO     Uploaded task 'L_MMI=11.20;W_MMI=4.80' with task_id                               ]8;id=582153;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=444552;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     '9178c6be-195b-4891-b68a-7a61fc608345'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:19] INFO     Uploaded task 'L_MMI=11.20;W_MMI=4.90' with task_id                               ]8;id=291750;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=137555;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     '027d83ec-a0fe-4983-98a0-0b55fd00eb16'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:21] INFO     Uploaded task 'L_MMI=11.20;W_MMI=5.00' with task_id                               ]8;id=40433;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=618998;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#120\120]8;;\
#                     '7d19bbb4-e97a-40cb-a40d-c31bdd92767c'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:06:28] Started working on Batch.                                                               ]8;id=114074;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\container.py\container.py]8;;\:]8;id=997812;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\container.py#354\354]8;;\
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:11] Batch complete.                                                                         ]8;id=347754;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\container.py\container.py]8;;\:]8;id=701387;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\container.py#375\375]8;;\

# %% [markdown]
# Parse flux data into numpy arrays.

# %%
T1 = np.zeros((len(L_MMIs), len(W_MMIs)))
T2 = np.zeros((len(L_MMIs), len(W_MMIs)))
for i, L_MMI in enumerate(L_MMIs):
    for j, W_MMI in enumerate(W_MMIs):
        sim_data = batch_results[f'L_MMI={L_MMI:.2f};W_MMI={W_MMI:.2f}']
        t1 = sim_data['flux1'].flux
        T1[i,j] = t1[50]   #the index 50 corresponds to the wavelength of 1550 nm
        t2 = sim_data['flux2'].flux
        T2[i,j] = t2[50]
# Out:
# [18:24:11] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=93269;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=709225;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\22529759-6b8e-48ee-a2b1-eb8ba8179251.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:13] INFO     loading SimulationData from data\22529759-6b8e-48ee-a2b1-eb8ba8179251.hdf5        ]8;id=329249;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=394375;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
# [18:24:14] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=533966;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=64240;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\161dd6fd-3e35-4c1c-baed-4f7791a4183f.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:16] INFO     loading SimulationData from data\161dd6fd-3e35-4c1c-baed-4f7791a4183f.hdf5        ]8;id=983085;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=285714;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
# [18:24:17] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=349930;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=306952;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\afabd316-98b4-4daf-ae84-210ca781b932.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:19] INFO     loading SimulationData from data\afabd316-98b4-4daf-ae84-210ca781b932.hdf5        ]8;id=66932;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=473024;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
# [18:24:20] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=334003;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=755336;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\82a2e1c6-fd1d-4fce-a4e9-e6ab22ba92d7.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:22] INFO     loading SimulationData from data\82a2e1c6-fd1d-4fce-a4e9-e6ab22ba92d7.hdf5        ]8;id=528453;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=995682;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
# [18:24:23] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=914574;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=250340;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\3b3fbbd3-2f4c-461d-9ded-e35287ae22b8.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:25] INFO     loading SimulationData from data\3b3fbbd3-2f4c-461d-9ded-e35287ae22b8.hdf5        ]8;id=534852;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=161900;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
#            INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=424481;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=878368;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\ac756e70-09df-4c3d-b8f2-cc2bfa737492.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:28] INFO     loading SimulationData from data\ac756e70-09df-4c3d-b8f2-cc2bfa737492.hdf5        ]8;id=38256;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=223080;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
#            INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=211327;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=876305;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\9178c6be-195b-4891-b68a-7a61fc608345.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:30] INFO     loading SimulationData from data\9178c6be-195b-4891-b68a-7a61fc608345.hdf5        ]8;id=354944;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=987176;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
# [18:24:31] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=957094;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=224737;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\027d83ec-a0fe-4983-98a0-0b55fd00eb16.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:33] INFO     loading SimulationData from data\027d83ec-a0fe-4983-98a0-0b55fd00eb16.hdf5        ]8;id=976858;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=31656;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\
# [18:24:34] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=785204;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=748443;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#581\581]8;;\
#                     "data\7d19bbb4-e97a-40cb-a40d-c31bdd92767c.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [18:24:36] INFO     loading SimulationData from data\7d19bbb4-e97a-40cb-a40d-c31bdd92767c.hdf5        ]8;id=874646;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=686461;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\

# %% [markdown]
# Visualize power difference between outputs as well as the excess loss. The optimal design would have both values as close to 0 as possible. From the plots, we can see that in this parameter range, the smallest power different does not coincide with the lowest excess loss. If we prioritize small power difference, for example, L_MMI = 11.15 $\mu m$ and W_MMI = 4.9 $\mu m$ would be a good design choice.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))
plt.sca(ax1)
plt.pcolor(W_MMIs, L_MMIs, np.abs(T1-T2), vmin=0, vmax=0.02, cmap='binary')
plt.colorbar()
plt.title('Power difference between inner and outer waveguides')
plt.xlabel('W_MMI ($\mu m$)')
plt.ylabel('L_MMI ($\mu m$)')
plt.sca(ax2)
plt.pcolor(W_MMIs, L_MMIs, -10*np.log10(2*(T1+T2)), vmin=0, vmax=0.25, cmap='binary')
plt.colorbar()
plt.title('Excess loss (dB)')
plt.xlabel('W_MMI ($\mu m$)')
plt.ylabel('L_MMI ($\mu m$)')

# %% [markdown]
# Plot field intensity for the optimal design.

# %%
sim_data = batch_results['L_MMI=11.15;W_MMI=4.90']
f, ax = plt.subplots(1, 1, figsize=(10,10))
sim_data.plot_field('field', 'int', ax = ax, f=freq0)
# Out:
# [18:24:37] INFO     loading SimulationData from data\3b3fbbd3-2f4c-461d-9ded-e35287ae22b8.hdf5        ]8;id=522174;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=134702;file://C:\Users\xinzh\Anaconda3\envs\tidy3d_dev\lib\site-packages\tidy3d_beta-1.8.0-py3.10.egg\tidy3d\web\webapi.py#403\403]8;;\

# %% [markdown]
# Plot transmission on each output waveguide as well as the total excess loss. For this design, at the central wavelength of 1.55 $\mu m$, the power on each power is roughly equal. The total excess loss is below 0.2 dB.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))
T1 = sim_data['flux1'].flux
T2 = sim_data['flux2'].flux

plt.sca(ax1)
plt.plot(ldas, T1, ldas, T2)
plt.vlines(x=1.55, ymin=0.1, ymax=0.3, colors='black', ls='--')
plt.xlabel('Wavelength ($\mu m$)')
plt.ylabel('Transmission to output')
plt.legend(('Inner output', 'Outer outport'))

plt.sca(ax2)
excess_loss = -10*np.log10(2*(T1+T2))
plt.plot(ldas, excess_loss)
plt.vlines(x=1.55, ymin=0, ymax=1, colors='black', ls='--')
plt.hlines(y=excess_loss[50], xmin=1.45, xmax=1.65, colors='black', ls='--')
plt.xlabel('Wavelength ($\mu m$)')
plt.ylabel('Excess loss (dB)')

# %% [markdown]
# In principle, the design can be further optimized by tuning other parameters such as gap size, tapper width, etc. if even lower excess loss is required.
# Finally, we can see the mode decomposition at the inner output waveguide. The fundamental mode is still dominant.

# %%
mode_amp = sim_data['mode1'].amps.sel(direction="+")
mode_power = np.abs(mode_amp)**2/T1
plt.plot(ldas, mode_power)
plt.xlabel('Wavelength ($\mu m$)')
plt.ylabel('Power fraction of the modes (%)')
plt.legend(["Mode 0", "Mode 1", "Mode 2", "Mode 3", "Mode 4"])
