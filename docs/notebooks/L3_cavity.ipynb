# %% [markdown]
# ## Photonic crystal cavity
#
# In this notebook, we will simulate the commonly used L3 photonic crystal cavity composed of three missing holes in a hexagonal lattice of holes in a silicon slab.

# %%
# standard python imports
import numpy as np
import matplotlib.pyplot as plt

# tidy3D import
import tidy3d as td
from tidy3d import web

# %% [markdown]
# ### Coarse simulation
#
# We will first run a broadband simulation to examine the spectrum, and zone in on the fundamental mode of the cavity. We start with defining some general parameters. We will use a fairly low spatial resolution for this initaly simulation. It's worth remembering that the PML extend **beyond** the simulation domain, so we don't need to worry about them covering some of the PhC holes. The one thing we have to remember is to extend the slab through the PML.

# %%
# Number of PhC periods in x and y directions
Nx, Ny = 16, 12

# Lattice constant of the PhC in micron
alattice = 0.4

# Regular PhC lattice parameters
ra = 0.25 * alattice # hole radius
d_slab = 0.22        # slab thickness
n_slab = 3.48        # refractive index of the slab

# Materials - air and silicon
air = td.Medium()
si = td.Medium(permittivity=n_slab**2)

# Mesh step in x, y, z, in micron
dl = 0.04
grid_size = [dl, dl*np.sqrt(3)/2, dl]

# Central frequency around which we'll look for the cavity mode (Hz)
freq0 = 2e14

# Source bandwidth (Hz)
fwidth = 4e13

# Simulation run time (s)
run_time = 20/fwidth

# Simulation domain size (micron)
sim_size = [(Nx+2)*alattice, ((Ny+1)*alattice)*np.sqrt(3)/2, 4]

# %% [markdown]
# Next, we define the positions of the holes that make the photonic crystal structure.

# %%
# Define x and y positions in one quadrant of the simulation domain
xp, yp = [], []
nx, ny = Nx//2 + 1, Ny//2 + 1
for iy in range(ny):
    for ix in range(nx):
        xp.append(ix + (iy%2)*0.5)
        yp.append(iy*np.sqrt(3)/2)

# Remove the first two holes to make the L3 defect
xp = xp[2:]
yp = yp[2:]

# Append holes for the other three quadrants
xf, yf = [], []
for x, y in zip(xp, yp):
    xf += [x, x, -x]
    yf += [y, -y, y]
    if x > 0 and y > 0:
        xf += [-x]
        yf += [-y]

# %% [markdown]
# Initialize all structures.

# %%
slab = td.Structure(
    geometry=td.Box(center=[0, 0, 0], size=[td.inf, td.inf, d_slab]), 
    medium=si
)

holes = []
for x, y in zip(xf, yf):
    holes.append(
        td.Structure(
            geometry=td.Cylinder(
                center = (np.array([x, y, 0])*alattice).tolist(),
                axis = 2,
                radius = ra,
                length = d_slab
            ),
            medium = air
        )
    )

# %% [markdown]
# Initialize the source. We are looking for the fundamental mode of the L3 cavity, so we use a y-polarized  source at the center of the cavity.

# %%
source = td.VolumeSource(
    center=(0, 0, 0),
    size=(0,0,0),
    source_time=td.GaussianPulse(
        freq0=freq0,
        fwidth=fwidth),
    polarization='Ey')

# %%
source.source_time.plot(np.linspace(0, run_time, 1001))
plt.show()

# %% [markdown]
# Finally, we also place a time monitor in the same location as the source. We set the time monitor starting time to be after the source decay, such that we can exclude the source signature from the recorded spectrum.

# %%
t_start = 1e-13
tmonitor = td.FieldTimeMonitor(center=[0, 0, 0], size=[0, 0, 0], start=t_start, name='field')

# %% [markdown]
# Initialize the simulation and visualize the structure.

# %%
sim = td.Simulation(
    size=sim_size, 
    grid_size=grid_size, 
    structures=[slab]+holes, 
    sources=[source],
    monitors=[tmonitor],
    run_time=run_time,
    pml_layers=3*[td.PML()])

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
sim.plot_eps(z=0, ax=ax[0]);
sim.plot_eps(x=0, ax=ax[1]);

# %% [markdown]
# ### Run simulation and examine the spectrum
#
# Now that the simulation is constructed, we can run it using the `web` API of Tidy3D. First, we submit the project.

# %%
# Submit a project to the cluster
job = web.Job(simulation=sim, task_name='L3 low res')
job.upload()
job.start()
# Out:
# [19:15:30] INFO     Uploaded task 'L3 low res' with task_id                      ]8;id=563424;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:84
#                     '569a0ed0-cefd-4f22-8113-1230541651c9'.

# %% [markdown]
# And we can continuously monitor the status until the run is succsessful.

# %%
job.monitor()
# Out:
# Output()
# [19:15:39] status = preprocess                                               ]8;id=863794;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:118
# [19:16:01] status = running                                                  ]8;id=841611;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:118
# [19:16:18] status = postprocess                                              ]8;id=461910;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:118
# [19:16:28] status = visualize                                                ]8;id=746925;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:118
# [19:16:33] status = success                                                  ]8;id=812094;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/container.py\container.py]8;;\:118
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# Once the run is successful, we can download the results and load them in the `td.SimulationData` object.

# %%
sim_data = job.load(path='data/sim_data.hdf5')
# Out:
# [19:16:33] INFO     downloading file "simulation.json" to                       ]8;id=92956;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:393
#                     "data/simulation.json"
# Output()
# [19:16:34] INFO     downloading file "monitor_data.hdf5" to                     ]8;id=634035;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:393
#                     "data/monitor_data.hdf5"
# Output()
#            INFO     downloading file "tidy3d.log" to "data/tidy3d.log"          ]8;id=475311;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:393
# Output()
#            INFO     exporting SimulationData to data/sim_data.hdf5              ]8;id=77415;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:266
#            INFO     loading SimulationData from data/sim_data.hdf5              ]8;id=932279;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:302

# %% [markdown]
# We finally plot the time dependence of the field in the center of the cavity, and the spectrum computed using a Fourier transform of that field. For the latter, we use the in-built `dft_spectrum` function.

# %%
# Get data from the TimeMonitor
tdata = sim_data['field']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))


# Plot time dependence 
tdata.Ey.plot(ax=ax1)
# ax[0].set_xlabel("Time [s]")
# ax[0].set_ylabel("Electric field [a.u.]");
# ax[0].set_title("Ey vs. time")

# Make frequency mesh and plot spectrum
# dt = tmesh[1] - tmesh[0]
# fmesh = np.linspace(1.6e14, 2.5e14, 101)

# ax[1].plot(fmesh, np.abs(td.dft_spectrum(Ey, dt, fmesh)))
# ax[1].set_xlim(1.7e14, 2.5e14)
# ax[1].set_xlabel("Frequency [Hz]")
# ax[1].set_ylabel("Electric field [a.u.]");
# ax[1].set_title("Spectrum");
# Out:
# [<matplotlib.lines.Line2D object at 0x12ee731f0>]

# %% [markdown]
# We see a big peak close to `f = 195THz`, which is most likely what we are looking for, because a) the fundamental mode is the longest-lived and b) we use a y-polarized source at the center of the simulation domain, which does not excite some of the other modes. Next, we refine the simulation and compute the field profile of this fundamental mode.

# %% [markdown]
# ### Refine simulation, use symmetries, get mode profile
#
# Now that we've seen a clear resonant peak, we can increase the resolution of the simulation to obtain more accurate results, and to get a high-resolution image of the cavity mode. We will also demonstrate how to use reflection symmetries. We center the source frequency close to the peak of the spectrum above, and decrease the bandwidth to exclude any other modes. We will also double the spatial resolution, making it 20 pixels per lattice period.

# %%
# New target frequency based on spectrum above
freq0 = 1.95e14

# Narrow-bandwidth source
source = td.VolumeSource(
    size=(0,0,0),
    center=(0, 0, 0),
    source_time=td.GaussianPulse(
        freq0=freq0,
        fwidth=fwidth/5),
    polarization='Ey')

# Also increase the run time a bit
run_time = 50/fwidth

# 20 pixels per lattice period
dl = 0.02
grid_size = [dl, dl*np.sqrt(3)/2, dl]

# %% [markdown]
# We can use both a time and a frequency monitor to obtain the field profile, each coming with advantages and disadvantages. The frequency monitor captures accurately the frequency-domain field, but that includes the source signature. On the other hand, examining the time-domain field can capture the "eigenmode" of the system, but only if all the other modes have decayed. This is, to a very large extent, the case in our simulation, so as we'll see the second approach works very well.
#
# **NB**: An important thing to note is that a 2D time monitor can result in a very large amount of data. Because of this, we will only record the fields near the last time step, setting `start = 0.9 * run_time` in the `FieldTimeMonitor`.

# %%
# Time and frequency monitors
tmonitor = td.FieldTimeMonitor(
    center=[0, 0, 0],
    size=[4, 2*np.sqrt(3), 0],
    start=run_time*0.9,
    name='final_time')

fmonitor = td.FieldMonitor(
    center=[0, 0, 0],
    size=[4, 2*np.sqrt(3), 0],
    freqs=[freq0],
    name='field')

# %% [markdown]
# Finally, we initialize the simulation, and also define reflection symmetries with respect to the x-, y-, and z-planes. Note that the eigenvalue of the symmetry (plus or minus one) has to be carefully determined, taking into account the vectorial nature of the electric field (and the pseudo-vector nature of the magnetic field). As an extra hint, positive symmetry is equivalent to a PMC plane, where the *normal* E-field component vanishes, while negative symmetry is equivalent to a PEC plane, where the *parallel* components of the E-field vanish. This is also the reason why in the visualization, we use blue and red to denote these symmetries, which are the same colors used for structures made of PMC and PEC material, respectively.

# %%
# Initialize simulation
sim = td.Simulation(
    size=sim_size, 
    grid_size=grid_size, 
    structures=[slab]+holes, 
    sources=[source], 
    monitors=[tmonitor, fmonitor],
    run_time=run_time,
    pml_layers=3*[td.PML()],
    symmetry=[1, -1, 1])

# %%
fig, ax = plt.subplots(1, figsize=(8, 6))
sim.plot_eps(z=0, ax=ax);

# %% [markdown]
# We run the simulation as above.

# %%
sim_data = web.run(sim, task_name='L3 high res', path='data/sim_data.hdf5')
# Out:
# [19:16:38] INFO     Uploaded task 'L3 high res' with task_id                     ]8;id=173904;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:84
#                     '5ca655dc-6775-4212-acf2-f88cd7e480f3'.
# Output()
# [19:16:39] status = queued                                                      ]8;id=216933;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:176
# [19:16:50] status = preprocess                                                  ]8;id=915466;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:176
# [19:17:12] status = running                                                     ]8;id=97662;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:176
# [19:17:24] status = postprocess                                                 ]8;id=355011;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:176
# [19:17:34] status = visualize                                                   ]8;id=749859;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:176
# [19:17:40] status = success                                                     ]8;id=656416;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:176
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [19:17:40] INFO     downloading file "simulation.json" to                       ]8;id=860604;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:393
#                     "data/simulation.json"
# Output()
# [19:17:41] INFO     downloading file "monitor_data.hdf5" to                     ]8;id=1157;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:393
#                     "data/monitor_data.hdf5"
# Output()
#            INFO     downloading file "tidy3d.log" to "data/tidy3d.log"          ]8;id=288055;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:393
# Output()
#            INFO     exporting SimulationData to data/sim_data.hdf5              ]8;id=682678;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:266
#            INFO     loading SimulationData from data/sim_data.hdf5              ]8;id=752388;file:///Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/web/webapi.py\webapi.py]8;;\:302

# %% [markdown]
# Finally, we plot the field recorded by the frequency monitor, with a rescaled colorbar in order to suppress the strongly dominant feature of the source in the center. On the other hand, the field stored in the time monitor reveals the eigenmode of the cavity.

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
# sim_data.plot_field('final_time', 'Ex', val='abs', z=0, time=run_time, ax=ax[0])
sim_data.plot_field('field', 'Ex', val='abs', freq=freq0, ax=ax[1]);
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /var/folders/jx/9y0mtn3s3zzb6mzgmsw6s6gr0000gn/T/ipykernel_7489/300310784.py:3 in         │
# │ <module>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/jx/9y0mtn3s3zzb6mzgmsw6s6gr0000gn/T/ipykernel_7489/300310784.py'            │
# │ /Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/comp │
# │ onents/viz.py:32 in _plot                                                                 │
# │                                                                                           │
# │    29 │   │   if kwargs.get("ax") is None:                                                │
# │    30 │   │   │   ax = make_ax()                                                          │
# │    31 │   │   │   kwargs["ax"] = ax                                                       │
# │ ❱  32 │   │   return plot(*args, **kwargs)                                                │
# │    33 │                                                                                   │
# │    34 │   return _plot                                                                    │
# │    35                                                                                     │
# │                                                                                           │
# │ /Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/comp │
# │ onents/data.py:764 in plot_field                                                          │
# │                                                                                           │
# │   761 │   │                                                                               │
# │   762 │   │   # get the field data component                                              │
# │   763 │   │   monitor_data.ensure_member_exists(field_name)                               │
# │ ❱ 764 │   │   xr_data = monitor_data.data_dict.get(field_name).data                       │
# │   765 │   │                                                                               │
# │   766 │   │   # select the frequency or time value                                        │
# │   767 │   │   if "f" in xr_data.coords:                                                   │
# │                                                                                           │
# │ /Users/twhughes/Documents/Flexcompute/tidy3d-docs/docs/notebooks/../../tidy3d/tidy3d/comp │
# │ onents/data.py:149 in data                                                                │
# │                                                                                           │
# │   146 │   │   # make DataArray                                                            │
# │   147 │   │   data_dict = self.dict()                                                     │
# │   148 │   │   coords = {dim: data_dict[dim] for dim in self._dims}                        │
# │ ❱ 149 │   │   data_array = Tidy3dDataArray(self.values, coords=coords)                    │
# │   150 │   │                                                                               │
# │   151 │   │   # assign attrs for xarray                                                   │
# │   152 │   │   if self.data_attrs:                                                         │
# │                                                                                           │
# │ /usr/local/lib/python3.9/site-packages/xarray/core/dataarray.py:410 in __init__           │
# │                                                                                           │
# │    407 │   │   │                                                                          │
# │    408 │   │   │   data = _check_data_shape(data, coords, dims)                           │
# │    409 │   │   │   data = as_compatible_data(data)                                        │
# │ ❱  410 │   │   │   coords, dims = _infer_coords_and_dims(data.shape, coords, dims)        │
# │    411 │   │   │   variable = Variable(dims, data, attrs, fastpath=True)                  │
# │    412 │   │   │   indexes = dict(                                                        │
# │    413 │   │   │   │   _extract_indexes_from_coords(coords)                               │
# │                                                                                           │
# │ /usr/local/lib/python3.9/site-packages/xarray/core/dataarray.py:158 in                    │
# │ _infer_coords_and_dims                                                                    │
# │                                                                                           │
# │    155 │   │                                                                              │
# │    156 │   │   for d, s in zip(v.dims, v.shape):                                          │
# │    157 │   │   │   if s != sizes[d]:                                                      │
# │ ❱  158 │   │   │   │   raise ValueError(                                                  │
# │    159 │   │   │   │   │   f"conflicting sizes for dimension {d!r}: "                     │
# │    160 │   │   │   │   │   f"length {sizes[d]} on the data but length {s} on "            │
# │    161 │   │   │   │   │   f"coordinate {k!r}"                                            │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: conflicting sizes for dimension 'x': length 100 on the data but length 200 on
# coordinate 'x'

# %%
sim_data['final_time'].data_dict['Ex'].values.shape
